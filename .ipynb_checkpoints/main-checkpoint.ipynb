# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import seaborn as sns
sns.set_style('dark')

# %%
data = pd.read_csv("dataset.csv")
data.head()
# Out:
#    Applicant_ID  Age  Gender Marital_Status  Dependents  Monthly_Income  \
# 0             1   35    Male        Married           2            6000
# 1             2   28  Female         Single           0            4000
# 2             3   45    Male        Married           3            8000
# 3             4   33  Female        Married           1            5500
# 4             5   40    Male       Divorced           0            7000
#
#   Employment_Status  Employment_Duration  Total_Monthly_Debt_Obligations  \
# 0          Employed                    5                            1500
# 1          Employed                    3                             800
# 2     Self-Employed                    8                            2000
# 3          Employed                    6                            1200
# 4          Employed                   10                            1500
#
#    Credit_Score  ...  Down_Payment_Amount  Interest_Rate  Installment_Amount  \
# 0           700  ...                 4000           0.08                 420
# 1           650  ...                 2000           0.07                 260
# 2           720  ...                 6000           0.09                 550
# 3           680  ...                 3000           0.08                 380
# 4           720  ...                 4000           0.08                 420
#
#    Housing_Status  Education_Level  Previous_Loan_Status  \
# 0             Own       Bachelor's        Not Applicable
# 1            Rent       Bachelor's        Not Applicable
# 2             Own         Master's  Previous Loan Closed
# 3             Own       Bachelor's        Not Applicable
# 4             Own      High School        Not Applicable
#
#    Previous_Loan_Amount Previous_Loan_Term Previous_Loan_Purpose  \
# 0                     0                  0        Not Applicable
# 1                     0                  0        Not Applicable
# 2                 25000                 60          Car Purchase
# 3                     0                  0        Not Applicable
# 4                     0                  0        Not Applicable
#
#   Loan_Eligibility
# 0         Eligible
# 1         Eligible
# 2     Not Eligible
# 3         Eligible
# 4         Eligible
#
# [5 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Applicant_ID                    45 non-null     int64
#  1   Age                             45 non-null     int64
#  2   Gender                          45 non-null     object
#  3   Marital_Status                  45 non-null     object
#  4   Dependents                      45 non-null     int64
#  5   Monthly_Income                  45 non-null     int64
#  6   Employment_Status               45 non-null     object
#  7   Employment_Duration             45 non-null     int64
#  8   Total_Monthly_Debt_Obligations  45 non-null     int64
#  9   Credit_Score                    45 non-null     int64
#  10  Credit_History_Length           45 non-null     int64
#  11  Debt_to_Income_Ratio            45 non-null     float64
#  12  Loan_Amount                     45 non-null     int64
#  13  Loan_Term                       45 non-null     int64
#  14  Down_Payment_Amount             45 non-null     int64
#  15  Interest_Rate                   45 non-null     float64
#  16  Installment_Amount              45 non-null     int64
#  17  Housing_Status                  45 non-null     object
#  18  Education_Level                 45 non-null     object
#  19  Previous_Loan_Status            45 non-null     object
#  20  Previous_Loan_Amount            45 non-null     int64
#  21  Previous_Loan_Term              45 non-null     int64
#  22  Previous_Loan_Purpose           45 non-null     object
#  23  Loan_Eligibility                45 non-null     object
# dtypes: float64(2), int64(14), object(8)
# memory usage: 8.6+ KB

# %%
data.drop('Applicant_ID', axis='columns', inplace=True)

# %%
data.head()
# Out:
#    Age  Gender Marital_Status  Dependents  Monthly_Income Employment_Status  \
# 0   35    Male        Married           2            6000          Employed
# 1   28  Female         Single           0            4000          Employed
# 2   45    Male        Married           3            8000     Self-Employed
# 3   33  Female        Married           1            5500          Employed
# 4   40    Male       Divorced           0            7000          Employed
#
#    Employment_Duration  Total_Monthly_Debt_Obligations  Credit_Score  \
# 0                    5                            1500           700
# 1                    3                             800           650
# 2                    8                            2000           720
# 3                    6                            1200           680
# 4                   10                            1500           720
#
#    Credit_History_Length  ...  Down_Payment_Amount  Interest_Rate  \
# 0                      3  ...                 4000           0.08
# 1                      2  ...                 2000           0.07
# 2                      5  ...                 6000           0.09
# 3                      4  ...                 3000           0.08
# 4                      7  ...                 4000           0.08
#
#    Installment_Amount  Housing_Status  Education_Level  Previous_Loan_Status  \
# 0                 420             Own       Bachelor's        Not Applicable
# 1                 260            Rent       Bachelor's        Not Applicable
# 2                 550             Own         Master's  Previous Loan Closed
# 3                 380             Own       Bachelor's        Not Applicable
# 4                 420             Own      High School        Not Applicable
#
#   Previous_Loan_Amount Previous_Loan_Term Previous_Loan_Purpose  \
# 0                    0                  0        Not Applicable
# 1                    0                  0        Not Applicable
# 2                25000                 60          Car Purchase
# 3                    0                  0        Not Applicable
# 4                    0                  0        Not Applicable
#
#    Loan_Eligibility
# 0          Eligible
# 1          Eligible
# 2      Not Eligible
# 3          Eligible
# 4          Eligible
#
# [5 rows x 23 columns]

# %%
feature_col = ['Loan_Eligibility','Gender','Employment_Status','Housing_Status','Previous_Loan_Status','Marital_Status','Education_Level', 'Previous_Loan_Purpose']
le = LabelEncoder()
for col in feature_col:
    data[col] = le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Age  Gender  Marital_Status  Dependents  Monthly_Income  Employment_Status  \
# 0   35       1               1           2            6000                  0
# 1   28       0               2           0            4000                  0
# 2   45       1               1           3            8000                  1
# 3   33       0               1           1            5500                  0
# 4   40       1               0           0            7000                  0
#
#    Employment_Duration  Total_Monthly_Debt_Obligations  Credit_Score  \
# 0                    5                            1500           700
# 1                    3                             800           650
# 2                    8                            2000           720
# 3                    6                            1200           680
# 4                   10                            1500           720
#
#    Credit_History_Length  ...  Down_Payment_Amount  Interest_Rate  \
# 0                      3  ...                 4000           0.08
# 1                      2  ...                 2000           0.07
# 2                      5  ...                 6000           0.09
# 3                      4  ...                 3000           0.08
# 4                      7  ...                 4000           0.08
#
#    Installment_Amount  Housing_Status  Education_Level  Previous_Loan_Status  \
# 0                 420               0                1                     0
# 1                 260               1                1                     0
# 2                 550               0                4                     1
# 3                 380               0                1                     0
# 4                 420               0                3                     0
#
#    Previous_Loan_Amount  Previous_Loan_Term  Previous_Loan_Purpose  \
# 0                     0                   0                      2
# 1                     0                   0                      2
# 2                 25000                  60                      0
# 3                     0                   0                      2
# 4                     0                   0                      2
#
#    Loan_Eligibility
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0
#
# [5 rows x 23 columns]

# %%
data.plot(figsize=(18, 8))
plt.show()

# %%
plt.figure(figsize=(18, 6))
plt.title("Relation Between Applicatoin Income vs Loan Amount ")

plt.grid()
plt.scatter(data['Monthly_Income'] , data['Loan_Amount'], c='k', marker='x')
plt.xlabel("Applicant Income")
plt.ylabel("Loan Amount")
plt.show()

# %%
# split dataset
X_train,X_test,y_train,y_test=train_test_split(data[['Age','Gender','Marital_Status','Dependents','Monthly_Income','Employment_Status','Employment_Duration','Total_Monthly_Debt_Obligations','Credit_Score','Credit_History_Length','Debt_to_Income_Ratio','Loan_Amount','Loan_Term','Down_Payment_Amount','Interest_Rate','Installment_Amount','Housing_Status','Education_Level','Previous_Loan_Status','Previous_Loan_Amount','Previous_Loan_Term','Previous_Loan_Purpose']],data.Loan_Eligibility,test_size=0.1)

# %%
len(X_train)
# Out:
# 40

# %%
#feature scaling
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 y_pred = knn.predict(X_test)
#       2 accuracy_score(y_test, y_pred)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:271, in KNeighborsClassifier.predict(self, X)
#     268         return self.classes_[np.argmax(probabilities, axis=1)]
#     269     # In that case, we do not need the distances to perform
#     270     # the weighting so we do not compute them.
# --> 271     neigh_ind = self.kneighbors(X, return_distance=False)
#     272     neigh_dist = None
#     273 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_base.py:850, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     843 use_pairwise_distances_reductions = (
#     844     self._fit_method == "brute"
#     845     and ArgKmin.is_usable_for(
#     846         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     847     )
#     848 )
#     849 if use_pairwise_distances_reductions:
# --> 850     results = ArgKmin.compute(
#     851         X=X,
#     852         Y=self._fit_X,
#     853         k=n_neighbors,
#     854         metric=self.effective_metric_,
#     855         metric_kwargs=self.effective_metric_params_,
#     856         strategy="auto",
#     857         return_distance=return_distance,
#     858     )
#     860 elif (
#     861     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     862 ):
#     863     results = _kneighbors_from_graph(
#     864         X, n_neighbors=n_neighbors, return_distance=return_distance
#     865     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:278, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     197 """Compute the argkmin reduction.
#     198
#     199 Parameters
#    (...)
#     275 returns.
#     276 """
#     277 if X.dtype == Y.dtype == np.float64:
# --> 278     return ArgKmin64.compute(
#     279         X=X,
#     280         Y=Y,
#     281         k=k,
#     282         metric=metric,
#     283         chunk_size=chunk_size,
#     284         metric_kwargs=metric_kwargs,
#     285         strategy=strategy,
#     286         return_distance=return_distance,
#     287     )
#     289 if X.dtype == Y.dtype == np.float32:
#     290     return ArgKmin32.compute(
#     291         X=X,
#     292         Y=Y,
#    (...)
#     298         return_distance=return_distance,
#     299     )
#
# File sklearn\\metrics\\_pairwise_distances_reduction\\_argkmin.pyx:90, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\fixes.py:94, in threadpool_limits(limits, user_api)
#      92     return controller.limit(limits=limits, user_api=user_api)
#      93 else:
# ---> 94     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:171, in threadpool_limits.__init__(self, limits, user_api)
#     167 def __init__(self, limits=None, user_api=None):
#     168     self._limits, self._user_api, self._prefixes = \
#     169         self._check_params(limits, user_api)
# --> 171     self._original_info = self._set_threadpool_limits()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:268, in threadpool_limits._set_threadpool_limits(self)
#     265 if self._limits is None:
#     266     return None
# --> 268 modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                           user_api=self._user_api)
#     270 for module in modules:
#     271     # self._limits is a dict {key: num_threads} where key is either
#     272     # a prefix or a user_api. If a module matches both, the limit
#     273     # corresponding to the prefix is chosed.
#     274     if module.prefix in self._limits:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:485, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     482         filepath = buf.value
#     484         # Store the module if it is supported and selected
# --> 485         self._make_module_from_path(filepath)
#     486 finally:
#     487     kernel_32.CloseHandle(h_process)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:515, in _ThreadpoolInfo._make_module_from_path(self, filepath)
#     513 if prefix in self.prefixes or user_api in self.user_api:
#     514     module_class = globals()[module_class]
# --> 515     module = module_class(filepath, prefix, user_api, internal_api)
#     516     self.modules.append(module)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:606, in _Module.__init__(self, filepath, prefix, user_api, internal_api)
#     604 self.internal_api = internal_api
#     605 self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606 self.version = self.get_version()
#     607 self.num_threads = self.get_num_threads()
#     608 self._get_extra_info()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\threadpoolctl.py:646, in _OpenBLASModule.get_version(self)
#     643 get_config = getattr(self._dynlib, "openblas_get_config",
#     644                      lambda: None)
#     645 get_config.restype = ctypes.c_char_p
# --> 646 config = get_config().split()
#     647 if config[0] == b"OpenBLAS":
#     648     return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
knn.predict(X_test)

# %%
knn.predict_proba(X_test)

# %%
X_test
